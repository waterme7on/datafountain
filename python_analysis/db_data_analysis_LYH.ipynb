# %%
import os
import pandas as pd
import numpy as np

# %%
db_path = "E:\datafountain\dataset_2\db\csv\db.csv"
db_data = pd.read_csv(db_path,engine="c",encoding="utf-8")

# %%
db_data.head()
# Out:
#    Unnamed: 0 destination_ip  destination_port protocol  \
# 0           0  10.24.249.104              3306    mysql
# 1           1  10.24.249.104              3306    mysql
# 2           2  10.24.249.104              3306    mysql
# 3           3  10.49.148.131              3306    mysql
# 4           4  10.49.148.131              3306    mysql
#
#                record_time      source_ip                    sql_info
# 0  2019-06-04 00:29:04.445   10.56.92.187  SET NAMES utf8 #4294967295
# 1  2019-06-04 00:29:04.446   10.56.92.187  set autocommit=04294967295
# 2  2019-06-04 00:29:04.447   10.56.92.187  SELECT cmd FROM  `command`
# 3  2019-06-04 00:29:04.628  10.49.148.130  SET NAMES utf8 #4294967295
# 4  2019-06-04 00:29:04.629  10.49.148.130  set autocommit=04294967295

# %%
db_data.shape
# Out:
# (3878893, 7)

# %%
db_protocol = db_data["protocol"]
db_protocol.groupby(db_protocol).count()
# Out:
# protocol
# mysql    3878893
# Name: protocol, dtype: int64

# %%
db_data.iloc[:1000000,:].to_csv("db_1.csv")
db_data.iloc[1000001:2000000,:].to_csv("db_2.csv")

# %%
db_data.iloc[2000001:3000000,:].to_csv("db_3.csv")
db_data.iloc[3000001:,:].to_csv("db_4.csv")

# %%
db_json_path = "E:\datafountain\dataset_2_origin\db"
os.listdir(db_json_path )
# Out:
# ['part-00000', 'part-00000.gz', 'part-00001', 'part-00001.gz']

# %%
db_sqlinfo = db_data["sql_info"]
db_sqlinfo.groupby(db_sqlinfo).count().to_csv("E:/datafountain/test1.csv",sep="$",encoding="utf_8_sig")
# Out:
# E:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-26-5367b5634a92> in <module>
#       1 db_sqlinfo = db_data["sql_info"]
# ----> 2 db_sqlinfo.groupby(db_sqlinfo).count().to_csv("E:/datafountain/test1.csv",sep="$",encoding="GBK")
#
# E:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in to_csv(self, *args, **kwargs)
#    4201                           stacklevel=2)
#    4202             kwargs["header"] = False  # Backwards compatibility.
# -> 4203         return self.to_frame().to_csv(**kwargs)
#    4204
#    4205     @Appender(generic._shared_docs['isna'] % _shared_doc_kwargs)
#
# E:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    3018                                  doublequote=doublequote,
#    3019                                  escapechar=escapechar, decimal=decimal)
# -> 3020         formatter.save()
#    3021
#    3022         if path_or_buf is None:
#
# E:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     170                 self.writer = UnicodeWriter(f, **writer_kwargs)
#     171
# --> 172             self._save()
#     173
#     174         finally:
#
# E:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py in _save(self)
#     286                 break
#     287
# --> 288             self._save_chunk(start_i, end_i)
#     289
#     290     def _save_chunk(self, start_i, end_i):
#
# E:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py in _save_chunk(self, start_i, end_i)
#     313
#     314         libwriters.write_csv_rows(self.data, ix, self.nlevels,
# --> 315                                   self.cols, self.writer)
#
# pandas/_libs/writers.pyx in pandas._libs.writers.write_csv_rows()
#
# UnicodeEncodeError: 'gbk' codec can't encode character '\ufffd' in position 154: illegal multibyte sequence

# %%
db_sqlinfo.shape
# Out:
# (3878893,)

# %%
db_sqlinfo.groupby(db_sqlinfo).describe()
# Out:
#                                                    count unique  \
# sql_info
# /* mysql-connector-java-5.1.21 ( Revision: ${bz...     2      1
# /* mysql-connector-java-5.1.21 ( Revision: ${bz...     2      1
# /* mysql-connector-java-5.1.21 ( Revision: ${bz...     2      1
# /* mysql-connector-java-5.1.21 ( Revision: ${bz...     2      1
# CALL sp_GetSrvModuleControlInfo('UserDataServer...     2      1
# CALL sp_GetSrvModuleControlInfo('UserDataServer...     1      1
# CALL sp_GetSrvModuleControlInfo('UserDataServer...     1      1
# CALL sp_GetSrvModuleControlInfo('UserDataServer...     1      1
# CALL sp_GetSrvModuleControlInfo('UserDataServer...     1      1
# CALL sp_GetSrvModuleControlInfo('UserDataServer...     1      1
# CALL sp_GetSrvModuleControlInfo('UserDataServer...     1      1
# CALL sp_GetSrvModuleControlInfo('UserDataServer...     1      1
# CALL sp_GetSrvModuleControlInfo('UserDataServer...     1      1
# CALL sp_GetSrvModuleControlInfo('UserDataServer...     1      1
# CALL sp_GetSrvModuleControlInfo('UserDataServer...     1      1
# CALL sp_GetSrvModuleControlInfo('UserDataServer...     1      1
# CALL sp_GetSrvModuleControlInfo('UserDataServer...     1      1
# CALL sp_GetSrvModuleControlInfo('UserDataServer...     1      1
# CALL sp_GetSrvModuleControlInfo('UserDataServer...     1      1
# CALL sp_GetSrvModuleControlInfo('UserTaskServer...     2      1
# CALL sp_GetSrvModuleControlInfo('UserTaskServer...     2      1
# CALL sp_GetSrvModuleControlInfo('UserTaskServer...     1      1
# INSERT INTO multiUI_tasktotal (userTask,taskDes...     1      1
# SELECT * FROM `tree` ee`95                             1      1
# SELECT * FROM coverpage WHERE  `category` = '1'...     1      1
# SELECT * FROM tjdata WHERE  tj_id = '2165'  AND...     1      1
# SELECT * FROM tjdata WHERE  tj_id = '2166'  AND...     1      1
# SELECT * FROM tjdata WHERE  tj_id = '2167'  AND...     1      1
# SELECT * FROM tjdata WHERE  tj_id = '2268'  AND...     1      1
# SELECT * FROM tjdata WHERE  tj_id = '2270'  AND...     1      1
# ...                                                  ...    ...
# set autocommit=0version) AS version FROM task_d...     1      1
# set autocommit=0wnload_task WHERE task_status=0...     1      1
# set autocommit=0ync_mail where send_flag=0098f6...     1      1
# set autocommit=0ync_mail where send_flag=06iO�...    30      1
# set autocommit=0ync_mail where send_flag=08.110...     1      1
# set autocommit=0ync_mail where send_flag=08.33....     1      1
# set autocommit=0ync_mail where send_flag=08.62....     1      1
# set autocommit=0ync_mail where send_flag=08.83....     1      1
# set autocommit=0ync_mail where send_flag=0=4 AN...     1      1
# set autocommit=0ync_mail where send_flag=0PEATA...    13      1
# set autocommit=0ync_mail where send_flag=0PEATA...     1      1
# set autocommit=0ync_mail where send_flag=0PEATA...     1      1
# set autocommit=0ync_mail where send_flag=0PEATA...     1      1
# set autocommit=0ync_mail where send_flag=0PEATA...     1      1
# set autocommit=0ync_mail where send_flag=0PEATA...     1      1
# set autocommit=0ync_mail where send_flag=0ere c...     1      1
# set autocommit=0ync_mail where send_flag=0ere c...     1      1
# set autocommit=0zjqid, is_leader FROM obbt.zjus...     1      1
# set autocommit=0zjqid, is_leader FROM obbt.zjus...     2      1
# set autocommit=0zjqid, is_leader FROM obbt.zjus...     1      1
# set autocommit=0zjqid, is_leader FROM obbt.zjus...     2      1
# set autocommit=0zjqid, is_leader FROM obbt.zjus...     2      1
# set autocommit=0zjqid, is_leader FROM obbt.zjus...     1      1
# set autocommit=0zjqid, is_leader FROM obbt.zjus...     1      1
# set autocommit=0zjqid, is_leader FROM obbt.zjus...     1      1
# set autocommit=0zjqid, is_leader FROM obbt.zjus...     1      1
# set autocommit=0��搵��t�!�s~��ZN                     187      1
# set names 'utf8'4294967295                            43      1
# show enginesor #4294967295                             1      1
# update multiUI_tasktotal set totalCase=33,total...     1      1
#
#                                                                                                   top  \
# sql_info
# /* mysql-connector-java-5.1.21 ( Revision: ${bz...  /* mysql-connector-java-5.1.21 ( Revision: ${b...
# /* mysql-connector-java-5.1.21 ( Revision: ${bz...  /* mysql-connector-java-5.1.21 ( Revision: ${b...
# /* mysql-connector-java-5.1.21 ( Revision: ${bz...  /* mysql-connector-java-5.1.21 ( Revision: ${b...
# /* mysql-connector-java-5.1.21 ( Revision: ${bz...  /* mysql-connector-java-5.1.21 ( Revision: ${b...
# CALL sp_GetSrvModuleControlInfo('UserDataServer...  CALL sp_GetSrvModuleControlInfo('UserDataServe...
# CALL sp_GetSrvModuleControlInfo('UserDataServer...  CALL sp_GetSrvModuleControlInfo('UserDataServe...
# CALL sp_GetSrvModuleControlInfo('UserDataServer...  CALL sp_GetSrvModuleControlInfo('UserDataServe...
# CALL sp_GetSrvModuleControlInfo('UserDataServer...  CALL sp_GetSrvModuleControlInfo('UserDataServe...
# CALL sp_GetSrvModuleControlInfo('UserDataServer...  CALL sp_GetSrvModuleControlInfo('UserDataServe...
# CALL sp_GetSrvModuleControlInfo('UserDataServer...  CALL sp_GetSrvModuleControlInfo('UserDataServe...
# CALL sp_GetSrvModuleControlInfo('UserDataServer...  CALL sp_GetSrvModuleControlInfo('UserDataServe...
# CALL sp_GetSrvModuleControlInfo('UserDataServer...  CALL sp_GetSrvModuleControlInfo('UserDataServe...
# CALL sp_GetSrvModuleControlInfo('UserDataServer...  CALL sp_GetSrvModuleControlInfo('UserDataServe...
# CALL sp_GetSrvModuleControlInfo('UserDataServer...  CALL sp_GetSrvModuleControlInfo('UserDataServe...
# CALL sp_GetSrvModuleControlInfo('UserDataServer...  CALL sp_GetSrvModuleControlInfo('UserDataServe...
# CALL sp_GetSrvModuleControlInfo('UserDataServer...  CALL sp_GetSrvModuleControlInfo('UserDataServe...
# CALL sp_GetSrvModuleControlInfo('UserDataServer...  CALL sp_GetSrvModuleControlInfo('UserDataServe...
# CALL sp_GetSrvModuleControlInfo('UserDataServer...  CALL sp_GetSrvModuleControlInfo('UserDataServe...
# CALL sp_GetSrvModuleControlInfo('UserDataServer...  CALL sp_GetSrvModuleControlInfo('UserDataServe...
# CALL sp_GetSrvModuleControlInfo('UserTaskServer...  CALL sp_GetSrvModuleControlInfo('UserTaskServe...
# CALL sp_GetSrvModuleControlInfo('UserTaskServer...  CALL sp_GetSrvModuleControlInfo('UserTaskServe...
# CALL sp_GetSrvModuleControlInfo('UserTaskServer...  CALL sp_GetSrvModuleControlInfo('UserTaskServe...
# INSERT INTO multiUI_tasktotal (userTask,taskDes...  INSERT INTO multiUI_tasktotal (userTask,taskDe...
# SELECT * FROM `tree` ee`95                                                 SELECT * FROM `tree` ee`95
# SELECT * FROM coverpage WHERE  `category` = '1'...  SELECT * FROM coverpage WHERE  `category` = '1...
# SELECT * FROM tjdata WHERE  tj_id = '2165'  AND...  SELECT * FROM tjdata WHERE  tj_id = '2165'  AN...
# SELECT * FROM tjdata WHERE  tj_id = '2166'  AND...  SELECT * FROM tjdata WHERE  tj_id = '2166'  AN...
# SELECT * FROM tjdata WHERE  tj_id = '2167'  AND...  SELECT * FROM tjdata WHERE  tj_id = '2167'  AN...
# SELECT * FROM tjdata WHERE  tj_id = '2268'  AND...  SELECT * FROM tjdata WHERE  tj_id = '2268'  AN...
# SELECT * FROM tjdata WHERE  tj_id = '2270'  AND...  SELECT * FROM tjdata WHERE  tj_id = '2270'  AN...
# ...                                                                                               ...
# set autocommit=0version) AS version FROM task_d...  set autocommit=0version) AS version FROM task_...
# set autocommit=0wnload_task WHERE task_status=0...  set autocommit=0wnload_task WHERE task_status=...
# set autocommit=0ync_mail where send_flag=0098f6...  set autocommit=0ync_mail where send_flag=0098f...
# set autocommit=0ync_mail where send_flag=06iO�...  set autocommit=0ync_mail where send_flag=06iO...
# set autocommit=0ync_mail where send_flag=08.110...  set autocommit=0ync_mail where send_flag=08.11...
# set autocommit=0ync_mail where send_flag=08.33....  set autocommit=0ync_mail where send_flag=08.33...
# set autocommit=0ync_mail where send_flag=08.62....  set autocommit=0ync_mail where send_flag=08.62...
# set autocommit=0ync_mail where send_flag=08.83....  set autocommit=0ync_mail where send_flag=08.83...
# set autocommit=0ync_mail where send_flag=0=4 AN...  set autocommit=0ync_mail where send_flag=0=4 A...
# set autocommit=0ync_mail where send_flag=0PEATA...  set autocommit=0ync_mail where send_flag=0PEAT...
# set autocommit=0ync_mail where send_flag=0PEATA...  set autocommit=0ync_mail where send_flag=0PEAT...
# set autocommit=0ync_mail where send_flag=0PEATA...  set autocommit=0ync_mail where send_flag=0PEAT...
# set autocommit=0ync_mail where send_flag=0PEATA...  set autocommit=0ync_mail where send_flag=0PEAT...
# set autocommit=0ync_mail where send_flag=0PEATA...  set autocommit=0ync_mail where send_flag=0PEAT...
# set autocommit=0ync_mail where send_flag=0PEATA...  set autocommit=0ync_mail where send_flag=0PEAT...
# set autocommit=0ync_mail where send_flag=0ere c...  set autocommit=0ync_mail where send_flag=0ere ...
# set autocommit=0ync_mail where send_flag=0ere c...  set autocommit=0ync_mail where send_flag=0ere ...
# set autocommit=0zjqid, is_leader FROM obbt.zjus...  set autocommit=0zjqid, is_leader FROM obbt.zju...
# set autocommit=0zjqid, is_leader FROM obbt.zjus...  set autocommit=0zjqid, is_leader FROM obbt.zju...
# set autocommit=0zjqid, is_leader FROM obbt.zjus...  set autocommit=0zjqid, is_leader FROM obbt.zju...
# set autocommit=0zjqid, is_leader FROM obbt.zjus...  set autocommit=0zjqid, is_leader FROM obbt.zju...
# set autocommit=0zjqid, is_leader FROM obbt.zjus...  set autocommit=0zjqid, is_leader FROM obbt.zju...
# set autocommit=0zjqid, is_leader FROM obbt.zjus...  set autocommit=0zjqid, is_leader FROM obbt.zju...
# set autocommit=0zjqid, is_leader FROM obbt.zjus...  set autocommit=0zjqid, is_leader FROM obbt.zju...
# set autocommit=0zjqid, is_leader FROM obbt.zjus...  set autocommit=0zjqid, is_leader FROM obbt.zju...
# set autocommit=0zjqid, is_leader FROM obbt.zjus...  set autocommit=0zjqid, is_leader FROM obbt.zju...
# set autocommit=0��搵��t�!�s~��ZN                                     set autocommit=0��搵��t�!�s~��ZN
# set names 'utf8'4294967295                                                 set names 'utf8'4294967295
# show enginesor #4294967295                                                 show enginesor #4294967295
# update multiUI_tasktotal set totalCase=33,total...  update multiUI_tasktotal set totalCase=33,tota...
#
#                                                    freq
# sql_info
# /* mysql-connector-java-5.1.21 ( Revision: ${bz...    2
# /* mysql-connector-java-5.1.21 ( Revision: ${bz...    2
# /* mysql-connector-java-5.1.21 ( Revision: ${bz...    2
# /* mysql-connector-java-5.1.21 ( Revision: ${bz...    2
# CALL sp_GetSrvModuleControlInfo('UserDataServer...    2
# CALL sp_GetSrvModuleControlInfo('UserDataServer...    1
# CALL sp_GetSrvModuleControlInfo('UserDataServer...    1
# CALL sp_GetSrvModuleControlInfo('UserDataServer...    1
# CALL sp_GetSrvModuleControlInfo('UserDataServer...    1
# CALL sp_GetSrvModuleControlInfo('UserDataServer...    1
# CALL sp_GetSrvModuleControlInfo('UserDataServer...    1
# CALL sp_GetSrvModuleControlInfo('UserDataServer...    1
# CALL sp_GetSrvModuleControlInfo('UserDataServer...    1
# CALL sp_GetSrvModuleControlInfo('UserDataServer...    1
# CALL sp_GetSrvModuleControlInfo('UserDataServer...    1
# CALL sp_GetSrvModuleControlInfo('UserDataServer...    1
# CALL sp_GetSrvModuleControlInfo('UserDataServer...    1
# CALL sp_GetSrvModuleControlInfo('UserDataServer...    1
# CALL sp_GetSrvModuleControlInfo('UserDataServer...    1
# CALL sp_GetSrvModuleControlInfo('UserTaskServer...    2
# CALL sp_GetSrvModuleControlInfo('UserTaskServer...    2
# CALL sp_GetSrvModuleControlInfo('UserTaskServer...    1
# INSERT INTO multiUI_tasktotal (userTask,taskDes...    1
# SELECT * FROM `tree` ee`95                            1
# SELECT * FROM coverpage WHERE  `category` = '1'...    1
# SELECT * FROM tjdata WHERE  tj_id = '2165'  AND...    1
# SELECT * FROM tjdata WHERE  tj_id = '2166'  AND...    1
# SELECT * FROM tjdata WHERE  tj_id = '2167'  AND...    1
# SELECT * FROM tjdata WHERE  tj_id = '2268'  AND...    1
# SELECT * FROM tjdata WHERE  tj_id = '2270'  AND...    1
# ...                                                 ...
# set autocommit=0version) AS version FROM task_d...    1
# set autocommit=0wnload_task WHERE task_status=0...    1
# set autocommit=0ync_mail where send_flag=0098f6...    1
# set autocommit=0ync_mail where send_flag=06iO�...   30
# set autocommit=0ync_mail where send_flag=08.110...    1
# set autocommit=0ync_mail where send_flag=08.33....    1
# set autocommit=0ync_mail where send_flag=08.62....    1
# set autocommit=0ync_mail where send_flag=08.83....    1
# set autocommit=0ync_mail where send_flag=0=4 AN...    1
# set autocommit=0ync_mail where send_flag=0PEATA...   13
# set autocommit=0ync_mail where send_flag=0PEATA...    1
# set autocommit=0ync_mail where send_flag=0PEATA...    1
# set autocommit=0ync_mail where send_flag=0PEATA...    1
# set autocommit=0ync_mail where send_flag=0PEATA...    1
# set autocommit=0ync_mail where send_flag=0PEATA...    1
# set autocommit=0ync_mail where send_flag=0ere c...    1
# set autocommit=0ync_mail where send_flag=0ere c...    1
# set autocommit=0zjqid, is_leader FROM obbt.zjus...    1
# set autocommit=0zjqid, is_leader FROM obbt.zjus...    2
# set autocommit=0zjqid, is_leader FROM obbt.zjus...    1
# set autocommit=0zjqid, is_leader FROM obbt.zjus...    2
# set autocommit=0zjqid, is_leader FROM obbt.zjus...    2
# set autocommit=0zjqid, is_leader FROM obbt.zjus...    1
# set autocommit=0zjqid, is_leader FROM obbt.zjus...    1
# set autocommit=0zjqid, is_leader FROM obbt.zjus...    1
# set autocommit=0zjqid, is_leader FROM obbt.zjus...    1
# set autocommit=0��搵��t�!�s~��ZN                    187
# set names 'utf8'4294967295                           43
# show enginesor #4294967295                            1
# update multiUI_tasktotal set totalCase=33,total...    1
#
# [1343 rows x 4 columns]

# %%
db_data = pd.read_json(db_json_path+"\part-00001")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-7c8eb69ee74e> in <module>
# ----> 1 db_data = pd.read_json(db_json_path+"\part-00001")
#
# E:\ProgramData\Anaconda3\lib\site-packages\pandas\io\json\json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     425         return json_reader
#     426
# --> 427     result = json_reader.read()
#     428     if should_close:
#     429         try:
#
# E:\ProgramData\Anaconda3\lib\site-packages\pandas\io\json\json.py in read(self)
#     535             )
#     536         else:
# --> 537             obj = self._get_object_parser(self.data)
#     538         self.close()
#     539         return obj
#
# E:\ProgramData\Anaconda3\lib\site-packages\pandas\io\json\json.py in _get_object_parser(self, json)
#     554         obj = None
#     555         if typ == 'frame':
# --> 556             obj = FrameParser(json, **kwargs).parse()
#     557
#     558         if typ == 'series' or obj is None:
#
# E:\ProgramData\Anaconda3\lib\site-packages\pandas\io\json\json.py in parse(self)
#     650
#     651         else:
# --> 652             self._parse_no_numpy()
#     653
#     654         if self.obj is None:
#
# E:\ProgramData\Anaconda3\lib\site-packages\pandas\io\json\json.py in _parse_no_numpy(self)
#     869         if orient == "columns":
#     870             self.obj = DataFrame(
# --> 871                 loads(json, precise_float=self.precise_float), dtype=None)
#     872         elif orient == "split":
#     873             decoded = {str(k): v for k, v in compat.iteritems(
#
# ValueError: Trailing data

# %%
db_json_path+"\part-00001"
# Out:
# 'E:\\datafountain\\dataset_2_origin\\db\\part-00001'
